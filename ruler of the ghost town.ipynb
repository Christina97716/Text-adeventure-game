# %%
#ruler of ghost town

"""
DocString:
    
    A) Introduction:
    The game contains 4 levels. If you answer all 3 questions you will be 
    crowned as The RULER of Ghost town or the KELLER. You also win ONE ticket
    to the best halloween party in San Francisco .
    Keller is defined as the person who will serve the king all his life
    
    level 0: Trail round
    level 1: easy 
    level 2: intermediate
    level 3: hard

"""

from sys import exit
from random import randint

def begin():
    global spooky_name
    
    
    print("\nHello and Welcome to The Ghost Town!!!\n")
    input(">Press enter to continue")
    print("My name is BABADOOK and i am going to decide your fate ")
    input(">Press enter to continue")

    
    print("This game wil lead you to being The Ruler of the Ghost town and also winning a ticket to the biggest halloween party in San Francisco AND if you lose uou will be crowned as the keller of the ruler ")
    input(">Press enter to continue")
    print("KELLER may defined as person who will be doomed to serve the ruler all his untill eternity")
    input(">Press enter to continue")
    print(f"\nJust kidding(NOT)!")
    input(">Press enter to continue")  
    print("""
Lets BEGIN

What's your name spooky name?""")

    spooky_name = input()
    
    print(f"\nWelcome {spooky_name}!!!!\n")
    
    
    print(f"Welcome to the Ghost Town  {spooky_name}.Lets have some fun this halloween")
    input(">Press enter to continue")


    
    Level_0()     

    
def Level_0():
    print(f" Welcome to LEVEL 0 ")
    input("<Press any key to continue>\n")
    print (f"""
 Our first LEVEL is O !

 This is a trial round, in this you will have to choose between any of the three options.
 Please Remember,This round doesnt count .
             
""")
    
    input("<Press any key to continue>\n")

        
    print(f"""
 {spooky_name},If you were confronted by a very powerfull soul what would you do ?
             1) Run away
             2) Invite the Ghost for a beer

""")
    Answer = input("> ")
    if "1" in Answer or "Run away" in Answer:
            
                print(f"""
 That's correct! Your Smart{spooky_name}!!!

""")
    input("<Press any key to continue>\n")
    Level_1()
    break
            
            else: 
                print(f"""
I must say,your very fearless{spooky_name}But,unfortunately your wrong but dont worry its just a trial round.

""") 
Level_1()
                    
def Level_1():

    print(f""" Our First round is PEPPER PEPPER!

              In this round you will have to choose any one of the three options.
              Good Luck {spooky_name}
             
""")
    input('<Press any key to continue>\n')

    chances = 2
    
    while chances > 0:
        
        print(f"""
 {spooky_name}, which is the most spicyest pepper in the world?
             1) Ghost Pepper
             2) Carolina Reapper
             3) Naga Viper
             

""")
        Answer = input("> ")
    if "2" in Answer or "Carolina Reapper" in Answer:
           
                print(f"""
 Wow.This is Amazing.

""")
                input('<Press any key to continue>\n')
                Level_2()
                break
            
    else:
                print(f"""
          Better Luck next time {spooky_name}.

""")
                chances -= 1


    if "2" in Answer or "Carolina Reapper" in Answer:
                
                print(f"""
         That's correct! You're amazing {spooky_name}!!!

""")
                input('<Press any key to continue>\n')
                Level_2()
                break
            
    else:
                print(f"""
           Better Luck next time{spooky_name}.

""")    
           
    fail()
# Out:
#   File "<ipython-input-7-0c751e052f9a>", line 87
#     else:
#     ^
# IndentationError: unexpected indent
